# %% [markdown]
# # Matplotlib
#
#
#
# *   Matplotlib is the most popular Python plotting library.
# *   It is a comprehensive library for creating static, animated, and interactive visualizations in Python
# *   It is useful for those working with Python and NumPy.
# *   It is a low-level libraray with a MATLAB-like interface which offers lots of freedom at the cost of faving to write more code.

# %% [markdown]
# # Advantages
#
# *   Extremely powerful
# *   Fast and efficient
# *   Open source
# *   Works well with many operating systems and graphic backends
# *   High-quality graphics and plots
# *   Ability to print and view a range of graphs
# *   Large community support and cross-platform support
# *   Full control over graph or plot styles

# %% [markdown]
# # Setting up Environment

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# load dataset
dataset = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")
dataset
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %% [markdown]
# # Basic Plots

# %% [markdown]
# ## Scatter Plot
#
#
# *   A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for different numeric variables.
# *   The position of each dot on the horizontal and vertical axis indicates values for an individual data point.
# *   Scatter plots are used to observe relationships between variables.

# %%
# create scatter plot
plt.scatter(dataset.crime_rate, dataset.percent_senior)
# show the figure
plt.show()

# %% [markdown]
# ### Is plt.show() always required?
#
#
# *   If Matplotlib is used in a terminal, scripts or specialized IDEs such as Spyder, Pycharm or VS Code, plat.show() is a must
# *   If Matplotlib is used in an iPython shell or a notebook as Jupyter Notebook or Colab Notebook, plt.show() is usually unnecesary.

# %% [markdown]
# ### Applications of Scatter Plot
#
#
# *   A scatter plot can be useful for identifying other patterns in data.
# *   We can divide data points into groups based on how closely sets of points cluster together.
# *   Scatter plots can also show if there are any unexpected gaps in the data and if there are any outlier points. (Look at the 2 points away from rest of the data in the scatter plot. Those are outliers.)
# *   This can be useful if we want to segment the data into different parts, like categorising users into different groups.

# %% [markdown]
# ## Line Plot
# A line chart is used to represent data over a continuous time span. It is generally used to show trend of a variable over time. Data values are plotted as points that are connected using line segments.

# %% [markdown]
# ### Create a Line Plot (with 2 **arguments**)

# %%
plt.plot(dataset.work_force, dataset.income)
plt.show()

# %% [markdown]
# ### Create a Line Plot (with a single argument)

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %% [markdown]
# *   You may be wondering why the x-axis ranges from 0-3 and the y-axis from 1-4.
# *   If you provide a list of n elements to the .plot() function, matplotlib will assume it is a sequence of y values, and automatically generates the x values for your as a range of n elements starting from 0.
# *   Since pythong ranges start with 0, the default list x has the smae length as y. Hence the x data will be [0, 1, 2, 3]. (Length same as y(4) but starts from 0 instead.)

# %% [markdown]
# ### Applications of Line Plot
# Using a line chart one can see the pattern of any dependent variable over time like share price, weather recordings (like temperature, precipitation or humidty)), etc.

# %% [markdown]
# ## Histogram
# A histogram is a graphical display of data using bars(rectangles) of different heights.

# %%
plt.hist(dataset.percent_senior)
plt.show()

# %% [markdown]
# ### Applications of Histogram
#
#
# *   Historgrams are a very common type of plots when we are looking at data like height and weight, stock prices, waiting time for a customer, etc which are continuous in nature.
# *   Histogram are good for showing general distributional features of dataset variables. You can see roughly where the peaks of the distribution are, whether the distribution is skewed or symmetric, and if there are any outliers.

# %% [markdown]
# ## Bar Plot
# Bar charts are one o the most common types of graphs and are used to show data associated with categorical variables.

# %% [markdown]
# ![image_f6582cfb0ad94fa8bbd6c1a5caa48686.png](data:image/png;base64,...)

# %% [markdown]
# ### Creating a Vertical Bar Plot

# %%
plt.bar(dataset.region, dataset.crime_rate)
plt.show()

# %% [markdown]
# ### Creating a Horizontal Bar Plot

# %%
plt.barh(dataset.region, dataset.crime_rate)
plt.show()

# %% [markdown]
# ### Bar Charts with multiple quantities
# When comparing several quantities and when changing one variable, we might want a bar chart where we have bars of one color for one quantity value.

# %% [markdown]
# ![image_ac9c91b9bdaa488ea6670e133440dedc.png](data:image/png;base64,...)

# %% [markdown]
# ### Stacked Bar Charts
# The stacked bar chart stacks bars that represent different groups on top of each other. The height of the resulting bar shows the combined result of the groups.

# %% [markdown]
# ![image_f2cfb1391fc7464a925f36ba15e8b6a7.png](data:image/png;base64,...)

# %% [markdown]
# ## Bar Chart vs Histogram
#
# Historgrams are a great way to show results of continuous data such as weight, height and etc.
# When the data is in categories such as Country or Favorite Movie, then we should use Bar Chart.
#
# ![image_2f1be5631f5242b8bc28e05a1e66fd3f.png](data:image/png;base64,...)

# %% [markdown]
# ## Pie Chart
#
#
# *   A pie chart (or a circle chart) is a circular statistical graphic, which is divided into slices(wedges) to illustrate numerical proportion.
# *   Imagine a pizza where different slices contain different toppings. Bigger the slice, larger the amount of that topping is present.
#
# ![image_22c4c086041540838c428ed1ed0bd044.png](data:image/png;base64,...)

# %%
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_share = [20, 25, 15, 10, 20]

#Explode the pie chart to emphasize a certain part or some parts (Firm B in this case)
# It is useful because it makes the highlighted portion more visible.
Explode = [0, 0.1, 0, 0, 0]

plt.pie(market_share, explode=Explode, labels=firms, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Applications of Pie Charts
#
#
# *   A pie chart is best used when trying to work out the composition of something. If you have categorical date then using a pie chart would work really well as each slice can represent a different category.
# *   Another good use for pie chart would be to compare areas of growth within a business such as turnover, profit and exposure.
# *   Try creating a pie chart to see how much money you spend in different areas.
